# %% [markdown]
# # Завдання для самоперевірки: обробка JSON, CSV, XML файлів у Python
#
# ## Загальні вимоги
# - Всі завдання повинні бути реалізовані з використанням функцій
# - Код має бути структурованим та читабельним
# - Обов'язково додавати обробку помилок
# - Використовувати docstring для документування функцій
#
# Можна виконати робоу з файлами JSON, CSV та XML
#
# * з папки `source/lesson_10/home/json`
# * та `source/lesson_10/home/csv`,
# * а також `source/lesson_10/home/xml`,
#
# АБО
# * роботи, що описані в цьому файлі.
#
# Тоді створіть окремі файли для кожного завдання та збережіть їх у відповідних папках.
#
# ---
#
# ## Частина 1: Робота з JSON файлами
#
# ### Завдання 1.1: Читання та запис JSON
# **Рівень складності:** Початковий
#
# Створіть функції для роботи з JSON файлами:
#
# ```python
# def read_json_file(filename):
#     """
#     Читає JSON файл та повертає його вміст як Python об'єкт.
#
#     Args:
#         filename (str): Шлях до JSON файла
#
#     Returns:
#         dict/list: Вміст JSON файла
#
#     Raises:
#         FileNotFoundError: Якщо файл не знайдено
#         json.JSONDecodeError: Якщо файл містить невалідний JSON
#     """
#     # Ваш код тут
#     pass
#
# def write_json_file(data, filename):
#     """
#     Записує Python об'єкт у JSON файл.
#
#     Args:
#         data (dict/list): Дані для запису
#         filename (str): Шлях до файла для запису
#
#     Returns:
#         bool: True якщо успішно записано, False в іншому випадку
#     """
#     # Ваш код тут
#     pass
# ```
#
# **Тестові дані:**
# ```json
# {
#     "students": [
#         {"name": "Анна", "age": 20, "grades": [85, 92, 78]},
#         {"name": "Петро", "age": 19, "grades": [90, 87, 95]},
#         {"name": "Марія", "age": 21, "grades": [88, 91, 84]}
#     ]
# }
# ```
#
# ### Завдання 1.2: Аналіз JSON даних
# **Рівень складності:** Середній
#
# Створіть функції для аналізу JSON даних про студентів:
#
# ```python
# def calculate_average_grade(student_data):
#     """
#     Розраховує середній бал для кожного студента.
#
#     Args:
#         student_data (dict): Дані про студентів
#
#     Returns:
#         dict: Словник з іменами студентів та їх середніми балами
#     """
#     # Ваш код тут
#     pass
#
# def find_top_student(student_data):
#     """
#     Знаходить студента з найвищим середнім балом.
#
#     Args:
#         student_data (dict): Дані про студентів
#
#     Returns:
#         dict: Інформація про найкращого студента
#     """
#     # Ваш код тут
#     pass
#
# def filter_students_by_age(student_data, min_age, max_age):
#     """
#     Фільтрує студентів за віком.
#
#     Args:
#         student_data (dict): Дані про студентів
#         min_age (int): Мінімальний вік
#         max_age (int): Максимальний вік
#
#     Returns:
#         list: Список студентів у заданому віковому діапазоні
#     """
#     # Ваш код тут
#     pass
# ```
#
# ### Завдання 1.3: Модифікація JSON структури
# **Рівень складності:** Підвищений
#
# ```python
# def add_student_statistics(student_data):
#     """
#     Додає статистику для кожного студента (середній бал, мін/макс оцінки).
#
#     Args:
#         student_data (dict): Дані про студентів
#
#     Returns:
#         dict: Модифікований словник з додатковою статистикою
#     """
#     # Ваш код тут
#     pass
#
# def merge_json_files(file1, file2, output_file):
#     """
#     Об'єднує два JSON файли зі списками студентів.
#
#     Args:
#         file1 (str): Шлях до першого файла
#         file2 (str): Шлях до другого файла
#         output_file (str): Шлях для збереження результату
#
#     Returns:
#         bool: True якщо успішно об'єднано
#     """
#     # Ваш код тут
#     pass
# ```
#
# ---
#
# ## Частина 2: Робота з CSV файлами
#
# ### Завдання 2.1: Основи роботи з CSV
# **Рівень складності:** Початковий
#
# ```python
# def read_csv_file(filename):
#     """
#     Читає CSV файл та повертає його вміст як список словників.
#
#     Args:
#         filename (str): Шлях до CSV файла
#
#     Returns:
#         list: Список словників, де кожен рядок - окремий словник
#     """
#     # Ваш код тут
#     pass
#
# def write_csv_file(data, filename, fieldnames):
#     """
#     Записує дані у CSV файл.
#
#     Args:
#         data (list): Список словників для запису
#         filename (str): Шлях до файла
#         fieldnames (list): Список назв колонок
#
#     Returns:
#         bool: True якщо успішно записано
#     """
#     # Ваш код тут
#     pass
# ```
#
# **Тестові дані (sales.csv):**
# ```csv
# date,product,category,quantity,price
# 2024-01-15,Laptop,Electronics,2,25000
# 2024-01-16,Mouse,Electronics,10,500
# 2024-01-17,Keyboard,Electronics,5,1200
# 2024-01-18,Chair,Furniture,3,3500
# 2024-01-19,Desk,Furniture,1,8000
# ```
#
# ### Завдання 2.2: Аналіз CSV даних
# **Рівень складності:** Середній
#
# ```python
# def calculate_total_sales(csv_data):
#     """
#     Розраховує загальну суму продажів.
#
#     Args:
#         csv_data (list): Дані з CSV файла
#
#     Returns:
#         float: Загальна сума продажів
#     """
#     # Ваш код тут
#     pass
#
# def get_sales_by_category(csv_data):
#     """
#     Групує продажі за категоріями.
#
#     Args:
#         csv_data (list): Дані з CSV файла
#
#     Returns:
#         dict: Словник з категоріями та сумами продажів
#     """
#     # Ваш код тут
#     pass
#
# def find_bestseller(csv_data):
#     """
#     Знаходить товар з найбільшою кількістю продажів.
#
#     Args:
#         csv_data (list): Дані з CSV файла
#
#     Returns:
#         dict: Інформація про найпопулярніший товар
#     """
#     # Ваш код тут
#     pass
#
# def filter_sales_by_date_range(csv_data, start_date, end_date):
#     """
#     Фільтрує продажі за діапазоном дат.
#
#     Args:
#         csv_data (list): Дані з CSV файла
#         start_date (str): Початкова дата (формат: YYYY-MM-DD)
#         end_date (str): Кінцева дата (формат: YYYY-MM-DD)
#
#     Returns:
#         list: Відфільтровані дані
#     """
#     # Ваш код тут
#     pass
# ```
#
# ### Завдання 2.3: Обробка великих CSV файлів
# **Рівень складності:** Підвищений
#
# ```python
# def process_large_csv_file(filename, chunk_size=1000):
#     """
#     Обробляє великий CSV файл частинами.
#
#     Args:
#         filename (str): Шлях до файла
#         chunk_size (int): Розмір частини для обробки
#
#     Yields:
#         list: Частина даних для обробки
#     """
#     # Ваш код тут
#     pass
#
# def create_sales_report(csv_data):
#     """
#     Створює звіт про продажі у вигляді нового CSV файла.
#
#     Args:
#         csv_data (list): Дані з CSV файла
#
#     Returns:
#         str: Шлях до створеного звіту
#     """
#     # Ваш код тут
#     pass
# ```
#
# ---
#
# ## Частина 3: Робота з XML файлами
#
# ### Завдання 3.1: Парсинг XML
# **Рівень складності:** Початковий
#
# ```python
# def parse_xml_file(filename):
#     """
#     Парсить XML файл та повертає root елемент.
#
#     Args:
#         filename (str): Шлях до XML файла
#
#     Returns:
#         xml.etree.ElementTree.Element: Root елемент XML
#     """
#     # Ваш код тут
#     pass
#
# def extract_text_from_xml(root, tag_name):
#     """
#     Витягує текст з усіх елементів з заданим тегом.
#
#     Args:
#         root: Root елемент XML
#         tag_name (str): Назва тега
#
#     Returns:
#         list: Список текстових значень
#     """
#     # Ваш код тут
#     pass
# ```
#
# **Тестові дані (books.xml):**
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <library>
#     <book id="1">
#         <title>Кобзар</title>
#         <author>Тарас Шевченко</author>
#         <year>1840</year>
#         <genre>Поезія</genre>
#         <price>250</price>
#     </book>
#     <book id="2">
#         <title>Лісова пісня</title>
#         <author>Леся Українка</author>
#         <year>1911</year>
#         <genre>Драма</genre>
#         <price>180</price>
#     </book>
#     <book id="3">
#         <title>Тіні забутих предків</title>
#         <author>Михайло Коцюбинський</author>
#         <year>1911</year>
#         <genre>Повість</genre>
#         <price>320</price>
#     </book>
# </library>
# ```
#
# ### Завдання 3.2: Аналіз XML даних
# **Рівень складності:** Середній
#
# ```python
# def get_books_by_author(xml_file, author_name):
#     """
#     Знаходить всі книги конкретного автора.
#
#     Args:
#         xml_file (str): Шлях до XML файла
#         author_name (str): Ім'я автора
#
#     Returns:
#         list: Список словників з інформацією про книги
#     """
#     # Ваш код тут
#     pass
#
# def calculate_average_book_price(xml_file):
#     """
#     Розраховує середню ціну книг.
#
#     Args:
#         xml_file (str): Шлях до XML файла
#
#     Returns:
#         float: Середня ціна книг
#     """
#     # Ваш код тут
#     pass
#
# def find_books_by_year_range(xml_file, start_year, end_year):
#     """
#     Знаходить книги, опубліковані в заданому діапазоні років.
#
#     Args:
#         xml_file (str): Шлях до XML файла
#         start_year (int): Початковий рік
#         end_year (int): Кінцевий рік
#
#     Returns:
#         list: Список книг у заданому діапазоні років
#     """
#     # Ваш код тут
#     pass
# ```
#
# ### Завдання 3.3: Створення та модифікація XML
# **Рівень складності:** Підвищений
#
# ```python
# def create_xml_from_dict(data, root_tag="root"):
#     """
#     Створює XML структуру з словника.
#
#     Args:
#         data (dict): Дані для конвертації
#         root_tag (str): Назва root елемента
#
#     Returns:
#         xml.etree.ElementTree.Element: Root елемент XML
#     """
#     # Ваш код тут
#     pass
#
# def add_book_to_xml(xml_file, book_data):
#     """
#     Додає нову книгу до XML файла.
#
#     Args:
#         xml_file (str): Шлях до XML файла
#         book_data (dict): Дані про нову книгу
#
#     Returns:
#         bool: True якщо успішно додано
#     """
#     # Ваш код тут
#     pass
#
# def convert_xml_to_json(xml_file, json_file):
#     """
#     Конвертує XML файл у JSON формат.
#
#     Args:
#         xml_file (str): Шлях до XML файла
#         json_file (str): Шлях для збереження JSON файла
#
#     Returns:
#         bool: True якщо успішно конвертовано
#     """
#     # Ваш код тут
#     pass
# ```
#
# ---
#
# ## Частина 4: Комплексні завдання
#
# ### Завдання 4.1: Універсальний конвертер
# **Рівень складності:** Високий
#
# ```python
# def convert_file_format(input_file, output_file, input_format, output_format):
#     """
#     Конвертує файл з одного формату в інший.
#
#     Supported formats: json, csv, xml
#
#     Args:
#         input_file (str): Шлях до вхідного файла
#         output_file (str): Шлях для вихідного файла
#         input_format (str): Формат вхідного файла
#         output_format (str): Формат вихідного файла
#
#     Returns:
#         bool: True якщо успішно конвертовано
#     """
#     # Ваш код тут
#     pass
#
# def validate_file_format(filename, expected_format):
#     """
#     Перевіряє, чи відповідає файл очікуваному формату.
#
#     Args:
#         filename (str): Шлях до файла
#         expected_format (str): Очікуваний формат (json, csv, xml)
#
#     Returns:
#         bool: True якщо формат відповідає
#     """
#     # Ваш код тут
#     pass
# ```
#
# ### Завдання 4.2: Система звітів
# **Рівень складності:** Високий
#
# ```python
# def generate_comprehensive_report(data_files, output_format="json"):
#     """
#     Генерує комплексний звіт з кількох файлів різних форматів.
#
#     Args:
#         data_files (list): Список шляхів до файлів даних
#         output_format (str): Формат вихідного звіту
#
#     Returns:
#         str: Шлях до створеного звіту
#     """
#     # Ваш код тут
#     pass
#
# def create_data_pipeline(input_files, transformations, output_file):
#     """
#     Створює pipeline для обробки даних з кількох файлів.
#
#     Args:
#         input_files (list): Список вхідних файлів
#         transformations (list): Список функцій трансформації
#         output_file (str): Шлях для вихідного файла
#
#     Returns:
#         bool: True якщо pipeline виконано успішно
#     """
#     # Ваш код тут
#     pass
# ```
#
# ---
#
# ## Критерії оцінки
#
# ### Початковий рівень (1-3 бали)
# - Функції виконують базовий функціонал
# - Присутня мінімальна обробка помилок
# - Код працює з простими даними
#
# ### Середній рівень (4-6 балів)
# - Функції реалізують додатковий функціонал
# - Належна обробка помилок та валідація даних
# - Код оптимізований для роботи з різними типами даних
#
# ### Підвищений рівень (7-8 балів)
# - Всі функції реалізовані повністю
# - Комплексна обробка помилок
# - Оптимізація для роботи з великими файлами
# - Додаткові функції для аналізу даних
#
# ### Високий рівень (9-10 балів)
# - Виконані всі завдання включно з комплексними
# - Створено універсальні рішення
# - Імплементовано pipeline для обробки даних
# - Код добре документований та тестований
#
# ---
#
# ## Додаткові рекомендації
#
# 1. **Використовуйте стандартні бібліотеки:** `json`, `csv`, `xml.etree.ElementTree`
# 2. **Додайте логування:** Використовуйте модуль `logging` для відстеження роботи функцій
# 3. **Тестування:** Створіть тестові файли для перевірки функцій
# 4. **Документація:** Додайте docstring для всіх функцій
# 5. **Обробка помилок:** Використовуйте try-except блоки для обробки виняткових ситуацій
#
# ## Приклад тестування
#
# ```python
# def test_json_functions():
#     """Приклад тестування функцій для роботи з JSON."""
#     # Тест читання JSON файла
#     test_data = {"test": "data"}
#     write_json_file(test_data, "test.json")
#     result = read_json_file("test.json")
#     assert result == test_data, "JSON читання/запис не працює правильно"
#
#     print("Всі тести пройдено успішно!")
#
# if __name__ == "__main__":
#     test_json_functions()
# ```
#
# ---
#
# **Успіхів у вивченні обробки файлів у Python!**
