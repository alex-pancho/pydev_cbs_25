# %% [markdown]
# # Вступ до Django. Архітектура курсу та що ми будемо будувати
#
# ---
#
# ## 1. Мета курсу
#
# Цей курс створений для того, щоб:
#
# * навчити створювати **повноцінні веб‑додатки на Django**;
# * зрозуміти, як працює backend у реальних проєктах;
# * пройти шлях **від ідеї до production‑деплою**;
# * навчитися працювати з Django як розробник або QA.
#
# 📌 Наприкінці курсу у вас буде **реальний проєкт**, який можна показати на співбесіді.
#
# ---
#
# ## 2. Що таке Django
#
# **Django** — це високорівневий Python‑фреймворк для створення веб‑додатків, який:
#
# * швидкий у розробці;
# * безпечний за замовчуванням;
# * масштабований;
# * використовується у production (Instagram, Disqus, Mozilla).
#
# Django дотримується принципу:
#
# > *“Don’t Repeat Yourself (DRY)”*
#
# ---
#
# ## 3. Django vs Flask vs FastAPI (коротко)
#
# | Фреймворк | Коли використовують                          |
# | --------- | -------------------------------------------- |
# | Django    | Повноцінні веб‑проєкти, admin, ORM, security |
# | Flask     | Маленькі сервіси, MVP                        |
# | FastAPI   | Швидкі API, microservices                    |
#
# 📌 У цьому курсі ми фокусуємось на **Django + Django REST Framework**.
#
# ---
#
# ## 4. Як працює веб‑додаток
#
# Спрощена схема:
#
# ```
# Browser → URL → Django URLconf → View → Model → Response
# ```
#
# Або з шаблонами:
#
# ```
# Request → View → Template → HTML → Browser
# ```
#
# Або з API:
#
# ```
# Request → View → Serializer → JSON
# ```
#
# ---
#
# ## 5. Архітектура Django (MTV)
#
# Django використовує шаблон **MTV**:
#
# * **Model** — робота з даними та БД
# * **Template** — HTML та відображення
# * **View** — бізнес‑логіка
#
# 📌 Це аналог MVC, але з іншими назвами.
#
# ---
#
# ## 6. Що ми будемо будувати в курсі
#
# Протягом курсу ми створимо:
#
# 🚗 **Сервіс обслуговування авто**:
#
# * клієнти
# * автомобілі
# * роботи по авто
# * вартість і оплата
# * API + UI
#
# Проєкт буде мати:
#
# * Django ORM
# * Forms
# * REST API (DRF)
# * Authentication
# * Deploy
#
# ---
#
# ## 7. Структура курсу
#
# 1. Вступ до Django
# 2. URLs та Views
# 3. Templates та Rendering
# 4. Forms та POST‑запити
# 5. Models та Migrations
# 6. Django ORM
# 7. Django REST Framework
# 8. Безпека у Django
# 9. Deploy Django
# 10. Підсумковий проєкт
#
# ---
#
# ## 8. Вимоги до студентів
#
# Необхідно:
#
# * базові знання Python
# * розуміння HTTP (GET / POST)
# * базове знання Git (clone, commit)
#
# 📌 Все інше ми розберемо з нуля.
#
# ---
#
# ## 9. Робоче середовище
#
# Ми будемо використовувати:
#
# * Python 3.10+
# * Django
# * Django REST Framework
# * SQLite (dev) / PostgreSQL (prod)
# * GitHub
#
# ---
#
# ## 10. Як виглядатиме типове заняття
#
# Кожна лекція:
#
# 1. Теорія
# 2. Живі приклади коду
# 3. Типові помилки
# 4. Практичне завдання
#
# ---
#
# ## 11. Приклад першого Django‑проєкту
#
# ```bash
# django-admin startproject carservice
# cd carservice
# python manage.py runserver
# ```
#
# В браузері:
#
# ```
# http://127.0.0.1:8000/
# ```
#
# 📌 Якщо сервер запустився — ви вже Django‑розробник 🙂
#
# ---
#
# ## 12. Типові помилки новачків
#
# ❌ Плутанина між project і app
#
# ❌ DEBUG=True у production
#
# ❌ Робота без virtualenv
#
# ❌ Страх читати документацію
#
# ---
#
# ## 13. Практичне завдання (Homework)
#
# 1. Встановити Python та Django
# 2. Створити перший Django‑проєкт
# 3. Запустити сервер
# 4. Зробити скріншот працюючого сервера
#
# ---
#
# ## 14. Підсумок
#
# На цьому уроці ви:
#
# * дізналися, що таке Django
# * зрозуміли архітектуру
# * побачили, що вас чекає в курсі
#
# ➡️ **Наступний урок: URLs та Views**
#
# ---
#
# 🎓 Ласкаво просимо до курсу Django
